# %% [markdown]
# Here, when implementing a separator with activation functions, while a -1 might give you correct answer using indicator functions, as sigmoid is an approximation of indicators, and at the boundary, $\sigma(x)=1/2$, you need to push it a little further forward to -0.5 to insure a correct decision boundary.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate data
x = np.linspace(-2.5,2,1000)
y = np.linspace(-0.5,3.5,1000)

X, Y = np.meshgrid(x,y)

def s(x):
  return np.exp(x)/(1+np.exp(x))

Z = s(9*(s(9*(X-0.5))+s(9*(0.5-Y))-0.5))

fig1, ax2 = plt.subplots(layout='constrained')
CS = ax2.contourf(X, Y, Z, 10, cmap=plt.cm.bone)

# Note that in the following, we explicitly pass in a subset of the contour
# levels used for the filled contours.  Alternatively, we could pass in
# additional levels to provide extra resolution, or leave out the *levels*
# keyword argument to use all of the original levels.

CS2 = ax2.contour(CS, levels=CS.levels[::2], colors='r')

ax2.set_title('Nonsense (3 masked regions)')
ax2.set_xlabel('word length anomaly')
ax2.set_ylabel('sentence length anomaly')

# Make a colorbar for the ContourSet returned by the contourf call.
cbar = fig1.colorbar(CS)
cbar.ax.set_ylabel('verbosity coefficient')
# Add the contour line levels to the colorbar
cbar.add_lines(CS2)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate data
x = np.linspace(-2.5,2,1000)
y = np.linspace(-0.5,3.5,1000)

X, Y = np.meshgrid(x,y)

def s(x):
  return np.exp(x)/(1+np.exp(x))

Z = s(9*(s(9*(X-0.5))+s(9*(0.5-Y))-1))

fig1, ax2 = plt.subplots(layout='constrained')
CS = ax2.contourf(X, Y, Z, 10, cmap=plt.cm.bone)

# Note that in the following, we explicitly pass in a subset of the contour
# levels used for the filled contours.  Alternatively, we could pass in
# additional levels to provide extra resolution, or leave out the *levels*
# keyword argument to use all of the original levels.

CS2 = ax2.contour(CS, levels=CS.levels[::2], colors='r')

ax2.set_title('Nonsense (3 masked regions)')
ax2.set_xlabel('word length anomaly')
ax2.set_ylabel('sentence length anomaly')

# Make a colorbar for the ContourSet returned by the contourf call.
cbar = fig1.colorbar(CS)
cbar.ax.set_ylabel('verbosity coefficient')
# Add the contour line levels to the colorbar
cbar.add_lines(CS2)
